# %%
import requests
from bs4 import BeautifulSoup
def exo1_2():

    UNI = requests.get("http://www.univ-orleans.fr")
    #print(UNI.text)


    soup = BeautifulSoup(UNI.text, 'lxml')




    #print(soup.text)

    #print(soup.h1)
    #print(soup.link)

    #print(len(soup.find_all('div')))


    div_header = soup.find_all('a', href=True)
    print(len(div_header))
    for lien in div_header:
        print(lien['href'])



#exo1_2()
# Out:
# -1
# 0
# 26
# 0
# 0
# 10
# -1
# 1
# 36
# 1
# 2
# 26
# -3
# 0
# 21
# -1
# 3
# 36
# 0
# 2
# 48
# 0
# 1
# 24
# 0
# 1
# 40
# 0
# 0
# 19
# -1
# 0
# 36
# 0
# 2
# 37
# 0
# 1
# 27
# 0
# 1
# 35
# 0
# 1
# 19
# -2
# 1
# 31
# -2
# 0
# 44
# 2
# 2
# 35
# -2
# 0
# 20
# 1
# 1
# 43
# 1
# 2
# 41
# 0
# 0
# 32
# 1
# 1
# 30
# 1
# 1
# 25
# -2
# 0
# 26
# 0
# 1
# 30
# 0
# 2
# 52
# 1
# 2
# 42
# 1
# 2
# 44
# 0
# 2
# 66
# 0
# 1
# 18
# 0
# 3
# 78
# 1
# 1
# 36
# -1
# 1
# 39
# -1
# 0
# 34
# -1
# 0
# 28
# 0
# 1
# 38
# -1
# 3
# 38
# -1
# 1
# 36
# 0
# 2
# 36
# 1
# 2
# 47
# -1
# 1
# 29
# 0
# 1
# 19
# 0
# 1
# 34
# 2
# 2
# 47
# 0
# 0
# 36
# -2
# 0
# 43
# 1
# 2
# 33
# -1
# 1
# 32
# -3
# 0
# 24
# Beautiful Soup class extraction
# -1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_5090/1649144546.py in <module>
#      88
#      89
# ---> 90 Exo3()
#
# /tmp/ipykernel_5090/1649144546.py in Exo3()
# ...
